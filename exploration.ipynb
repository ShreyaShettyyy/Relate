# %% [markdown]
# # Recommender System Exploration
# This notebook explores the Apriori Market Basket Analysis and Collaborative Filtering models.

# %%
import pandas as pd
from recommender import RecommenderSystem

df = pd.read_csv('transactions.csv')
df.head()

# %%
recommender = RecommenderSystem(df)
recommender.train_market_basket(min_support=0.1, min_threshold=1.0)

recommender.get_global_combination_recommendations()

# %%
recommender.get_personalized_recommendations(customer_id=101)

# %%
recommender.get_collaborative_recommendations(customer_id=102)
